# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import networkx as nx
import string

# %%
all_keys = '...'

table = str.maketrans('', '', string.ascii_lowercase)

pressed_only = all_keys.translate(table)

pressed_only
# Out:
# '...'

# %%
def getAllSubStrings(x, l=None, freq=False):
    if l == None:
        l = len(x)
    
    allSubStrings = [x[i:i+l] for i in range(0, len(x)) if len(x[i:i+l]) == l]

    if freq:
        return allSubStrings
    else:
        return set(allSubStrings)


def extract_freq(x, l=3, sort='value'):
    res = {}
    substrings = getAllSubStrings(pressed_only, l=l, freq=True)
    for idx in substrings:
        if idx not in res.keys():
            res[idx] = 1
        else:
            res[idx] += 1
    if sort == 'key':
        return dict(sorted(res.items(), key=lambda item: item[0], reverse=False))
    elif sort == 'value':
        return dict(sorted(res.items(), key=lambda item: item[1], reverse=True))


all_patterns = {}
for i in range(4, 11):
    all_patterns.update(extract_freq(pressed_only, l=i, sort='value'))
all_patterns = dict(sorted(all_patterns.items(), key=lambda item: item[1], reverse=True))
all_patterns
# Out:
# {'JJJJ': 70,
#  'JRJR': 54,
#  'RJRJ': 53,
#  'JRJJ': 52,
#  'RJJJ': 49,
#  'JJRJ': 43,
#  'JJJJJ': 42,
#  'JLRJ': 34,
#  'JRJRJ': 34,
#  'RJJR': 33,
#  'LJRJ': 29,
#  'JRRJ': 29,
#  'RJLR': 28,
#  'RJJJJ': 28,
#  'LRJJ': 27,
#  'JLJR': 27,
#  'JRJJJ': 27,
#  'JJJR': 26,
#  'RJLJ': 24,
#  'JJJL': 24,
#  'RJRJR': 24,
#  'JJJJJJ': 24,
#  'RJRJJ': 23,
#  'JJLR': 22,
#  'RRJJ': 22,
#  'JJRJR': 21,
#  'LRJL': 20,
#  'RJRR': 20,
#  'RJLRJ': 20,
#  'RJJRJ': 20,
#  'RJJL': 19,
#  'JRJL': 19,
#  'RRRJ': 19,
#  'RRJL': 19,
#  'RRJR': 19,
#  'JLJRJ': 19,
#  'JJJRJ': 19,
#  'JJRJJ': 18,
#  'RJJJJJ': 18,
#  'RJRJRJ': 18,
#  'JRLR': 17,
#  'JLRJJ': 17,
#  'JRJJR': 17,
#  'JJLJ': 16,
#  'RLRJ': 16,
#  'JRJRJR': 16,
#  'JJRR': 15,
#  'LRJR': 15,
#  'RJRL': 15,
#  'RJLJR': 15,
#  'JJJJR': 15,
#  'JRJJJJ': 15,
#  'JRJRJJ': 15,
#  'JRRR': 14,
#  'JRJRR': 14,
#  'JJJJJJJ': 14,
#  'LLLL': 13,
#  'JJJLR': 13,
#  'JJRRJ': 13,
#  'JJLRJ': 13,
#  'RJRLR': 13,
#  'RJLJRJ': 13,
#  'JRJRJRJ': 13,
#  'LLRJ': 12,
#  'RRRR': 12,
#  'LRRJ': 12,
#  'RLJR': 12,
#  'JJJJL': 12,
#  'RJJJL': 12,
#  'JRRJL': 12,
#  'RJLRJJ': 12,
#  'RJJRJR': 12,
#  'JLRL': 11,
#  'LJRR': 11,
#  'JLRJL': 11,
#  'LJRJJ': 11,
#  'LRJJJ': 11,
#  'RRJJJ': 11,
#  'RRJRJ': 11,
#  'JJJJRJ': 11,
#  'JJRJRJ': 11,
#  'JRJJRJ': 11,
#  'RJRJRJR': 11,
#  'JLJL': 10,
#  'JRJLR': 10,
#  'LRJJR': 10,
#  'JRLRJ': 10,
#  'LJRJJJ': 10,
#  'RJRJJJ': 10,
#  'RJJJJJJ': 10,
#  'JRJJJJJ': 10,
#  'JLJJ': 9,
#  'JJRL': 9,
#  'JLRR': 9,
#  'LRJLR': 9,
#  'RJJLJ': 9,
#  'LRJLJ': 9,
#  'RJJJR': 9,
#  'RJJRR': 9,
#  'JRRJJ': 9,
#  'RJRRR': 9,
#  'RRRRJ': 9,
#  'RJJLR': 9,
#  'JRJLJ': 9,
#  'LJRJL': 9,
#  'LJRJR': 9,
#  'RJRRJ': 9,
#  'JJJJJL': 9,
#  'RJRJJR': 9,
#  'JJJJJR': 9,
#  'JJRJRR': 9,
#  'LJJR': 8,
#  'RLRR': 8,
#  'JRLJ': 8,
#  'JJLRL': 8,
#  'LRJRJ': 8,
#  'JRJJL': 8,
#  'RRJLR': 8,
#  'RLRJL': 8,
#  'RRRJR': 8,
#  'JRRRJ': 8,
#  'LLLLL': 8,
#  'JRRJR': 8,
#  'LRJLRJ': 8,
#  'JLJRJJ': 8,
#  'JJJJLR': 8,
#  'JJJRJR': 8,
#  'RRJJJJ': 8,
#  'JJJRJJ': 8,
#  'JJRJJR': 8,
#  'JJJLRJ': 8,
#  'JRJRJJR': 8,
#  'RJJRJRR': 8,
#  'JRJRJRJR': 8,
#  'RJRJRJRJ': 8,
#  'RJLL': 7,
#  'JLLJ': 7,
#  'JJLL': 7,
#  'LRRR': 7,
#  'LLLR': 7,
#  'JJLJR': 7,
#  'JJJLJ': 7,
#  'LRRJJ': 7,
#  'LJRRJ': 7,
#  'RJLRJL': 7,
#  'JRJLRJ': 7,
#  'RJJRRJ': 7,
#  'JRJRRR': 7,
#  'JRJJJL': 7,
#  'RRRJRJ': 7,
#  'RJJRJJ': 7,
#  'JJRJJJ': 7,
#  'JLJRJJJ': 7,
#  'JJJRJRJ': 7,
#  'JJJJJRJ': 7,
#  'JJRJJRJ': 7,
#  'JRJJRJR': 7,
#  'JJRJRJJ': 7,
#  'RJJJJJJJ': 7,
#  'JJJJJJJJ': 7,
#  'LRLR': 6,
#  'LLJR': 6,
#  'LRLJ': 6,
#  'LJLJ': 6,
#  'JLLL': 6,
#  'LRJJL': 6,
#  'JLLJR': 6,
#  'JRRRR': 6,
#  'RRJLJ': 6,
#  'JJLJJ': 6,
#  'LLRJR': 6,
#  'JLRJR': 6,
#  'JRLRR': 6,
#  'RLRRJ': 6,
#  'RRJJR': 6,
#  'JLJRR': 6,
#  'RJRJL': 6,
#  'RJLJL': 6,
#  'RJLRR': 6,
#  'JLJLJ': 6,
#  'RRRJJ': 6,
#  'RLJRJ': 6,
#  'LLLRJ': 6,
#  'JRJRL': 6,
#  'RJJJRJ': 6,
#  'RJJJJR': 6,
#  'RRJLJR': 6,
#  'RJRLRR': 6,
#  'LJRRJL': 6,
#  'JLRJLJ': 6,
#  'JLRJJR': 6,
#  'JLRJJJ': 6,
#  'RJRLRJ': 6,
#  'LRJJRJ': 6,
#  'JLJRJL': 6,
#  'LRJLRJJ': 6,
#  'RJLJRJJ': 6,
#  'JJJJJJL': 6,
#  'JJJJRJJ': 6,
#  'RJRJJJJ': 6,
#  'RJLJRJJJ': 6,
#  'JJRJJRJR': 6,
#  'LJRL': 5,
#  'RLLR': 5,
#  'JLRLR': 5,
#  'RLRJJ': 5,
#  'RRRJL': 5,
#  'JLJJR': 5,
#  'LRJRL': 5,
#  'RRJJL': 5,
#  'JLRLJ': 5,
#  'LRLJR': 5,
#  'JRLJR': 5,
#  'JJJRR': 5,
#  'JLRRR': 5,
#  'LJLJR': 5,
#  'LLRJJ': 5,
#  'LLLLR': 5,
#  'RRJLL': 5,
#  'JLRJJL': 5,
#  'LRJLJR': 5,
#  'JJJLRL': 5,
#  'JJLRLR': 5,
#  'LRJJJJ': 5,
#  'JRJJJR': 5,
#  'JRJJRR': 5,
#  'JJRRJJ': 5,
#  'JRRJJJ': 5,
#  'LLRJRJ': 5,
#  'LRJRJJ': 5,
#  'JRJJLR': 5,
#  'RJJLRJ': 5,
#  'LRJRLR': 5,
#  'JRLRRJ': 5,
#  'JLJRRJ': 5,
#  'JRRJLR': 5,
#  'JLRLJR': 5,
#  'RLRJLR': 5,
#  'JRLRJL': 5,
#  'JJJRRJ': 5,
#  'JLJLJR': 5,
#  'JJLRJJ': 5,
#  'RJRRRJ': 5,
#  'LJRJRJ': 5,
#  'RRJRJR': 5,
#  'RJJJLR': 5,
#  'LLLLRJ': 5,
#  'JLJRJR': 5,
#  'LJRJLR': 5,
#  'LLLLLL': 5,
#  'JRJRRJ': 5,
#  'LRJLJRJ': 5,
#  'LJRJJJJ': 5,
#  'RJRJRJJ': 5,
#  'JJRJRRR': 5,
#  'RRJLJRJ': 5,
#  'RJRLRRJ': 5,
#  'JJJJJLR': 5,
#  'RLRJLRJ': 5,
#  'RJLRJJJ': 5,
#  'RJJJJJR': 5,
#  'RJLJRJL': 5,
#  'JJJJJJJL': 5,
#  'JRJJJJJJ': 5,
#  'JJJRJRJJ': 5,
#  'JRJRJRJRJ': 5,
#  'RJRJRJRJR': 5,
#  'JRLL': 4,
#  'LJLR': 4,
#  'JRLLR': 4,
#  'LRLRJ': 4,
#  'JJRJL': 4,
#  'LLJRJ': 4,
#  'LJJRJ': 4,
#  'JJJLL': 4,
#  'RLJRR': 4,
#  'RJJRL': 4,
#  'RRJRR': 4,
#  'JJRLJ': 4,
#  'JLRRJ': 4,
#  'JLLLL': 4,
#  'RRJRL': 4,
#  'JLRJLR': 4,
#  'JJJLJR': 4,
#  'JLLJRJ': 4,
#  'RJRRRR': 4,
#  'RRRRJL': 4,
#  'RJJJLJ': 4,
#  'RJRJJL': 4,
#  'JJLRJR': 4,
#  'RLRRJJ': 4,
#  'RRJJLJ': 4,
#  'RRJLRJ': 4,
#  'JRJLJR': 4,
#  'JJJJRR': 4,
#  'RJJLJJ': 4,
#  'JRJLJL': 4,
#  'LJRJLJ': 4,
#  'RRJLRR': 4,
#  'JRRRJJ': 4,
#  'RRRJJJ': 4,
#  'JRJRLR': 4,
#  'RRJRLR': 4,
#  'JRRJLL': 4,
#  'JJLRJL': 4,
#  'JJRRJL': 4,
#  'JJRRJR': 4,
#  'RJLJLJ': 4,
#  'RJRRJR': 4,
#  'JJJJLRL': 4,
#  'LRJJJJJ': 4,
#  'JRJLRJL': 4,
#  'RJJJJRJ': 4,
#  'JJJJRJR': 4,
#  'JJRJRJR': 4,
#  'RJRJJRR': 4,
#  'JRJJRRJ': 4,
#  'JRRJJJJ': 4,
#  'RRJJJJJ': 4,
#  'JJJJJJR': 4,
#  'JJJRJJR': 4,
#  'RJJRJRJ': 4,
#  'JRJRJJJ': 4,
#  'JRLRRJJ': 4,
#  'JLJRRJL': 4,
#  'RJLRJJR': 4,
#  'JJJJLRJ': 4,
#  'JLRJJJJ': 4,
#  'JJJJRRJ': 4,
#  'RJRJJRJ': 4,
#  'JJRJJJJ': 4,
#  'RJRLRJL': 4,
#  'JLRJJRJ': 4,
#  'JRJRRRJ': 4,
#  'JJJLRJJ': 4,
#  'RJJJRJR': 4,
#  'JJJRJJJ': 4,
#  'LJRJLRJ': 4,
#  'RJJJLRJ': 4,
#  'LRJJJJJJ': 4,
#  'JJRJRJRJ': 4,
#  'RJRJRJJR': 4,
#  'JJJJJJRJ': 4,
#  'JJJJJRJJ': 4,
#  'JJJRJJRJ': 4,
#  'JRJJRJRR': 4,
#  'RJJRJRRR': 4,
#  'RJRJJJJJ': 4,
#  'RJRLRRJJ': 4,
#  'RLRJLRJJ': 4,
#  'RJLRJJJJ': 4,
#  'JRJRJJRJ': 4,
#  'RJJJRJRJ': 4,
#  'RJJJJJJJJ': 4,
#  'JJRJJRJRR': 4,
#  'JRJRJRJRJR': 4,
#  'JLLR': 3,
#  'JRRL': 3,
#  'RRLR': 3,
#  'RLLRJ': 3,
#  'RJLLJ': 3,
#  'JLLRJ': 3,
#  'RJLJJ': 3,
#  'JJRLL': 3,
#  'LJRRR': 3,
#  'JLJLR': 3,
#  'JJLJL': 3,
#  'RLRJR': 3,
#  'RRRRR': 3,
#  'LJJRL': 3,
#  'LRRJR': 3,
#  'JJLLL': 3,
#  'LRRRR': 3,
#  'RJLLL': 3,
#  'RJJLJR': 3,
#  'RJJJJL': 3,
#  'JLRLRJ': 3,
#  'RLRJJJ': 3,
#  'JJJJLJ': 3,
#  'JJLJRJ': 3,
#  'JJJRJL': 3,
#  'JRRRRJ': 3,
#  'JJLJJR': 3,
#  'LJJRJJ': 3,
#  'JLRJRL': 3,
#  'LRRJJR': 3,
#  'JRRJJL': 3,
#  'JJLJRR': 3,
#  'JJRLLR': 3,
#  'RRRRJR': 3,
#  'RRJRJJ': 3,
#  'LRJRJR': 3,
#  'RRJJRJ': 3,
#  'JJRJJL': 3,
#  'JRJJLJ': 3,
#  'RRJRJL': 3,
#  'RJRJLJ': 3,
#  'RJJJLL': 3,
#  'LJRRRJ': 3,
#  'RRRJLR': 3,
#  'RJLRRR': 3,
#  'JRRRJR': 3,
#  'JRLRJJ': 3,
#  'LRJJJR': 3,
#  'JRRRRR': 3,
#  'RRRRRJ': 3,
#  'RJRJRR': 3,
#  'LJJRLJ': 3,
#  'JJRLJR': 3,
#  'JRLJRJ': 3,
#  'RLJRJR': 3,
#  'RJJLRL': 3,
#  'LRJJJL': 3,
#  'LLLRJR': 3,
#  'RJRJRL': 3,
#  'JRRJLJ': 3,
#  'RJRRJJ': 3,
#  'LRJJLR': 3,
#  'LLLLLR': 3,
#  'LLLRJJ': 3,
#  'LRLJRJ': 3,
#  'LRRRRJ': 3,
#  'JRRJRR': 3,
#  'RJRJLR': 3,
#  'LJLJRJ': 3,
#  'JRJRJL': 3,
#  'RJLRRJ': 3,
#  'JRRJRL': 3,
#  'RRJLLL': 3,
#  'RJLRJLR': 3,
#  'JLRJLRJ': 3,
#  'RJLRJJL': 3,
#  'RJJJJLR': 3,
#  'JJJLRLR': 3,
#  'JJLRLRJ': 3,
#  'JJJJJLJ': 3,
#  'JJJJLJR': 3,
#  'JRJJJRJ': 3,
#  'JJRRJJJ': 3,
#  'JRJRRRR': 3,
#  'LJRJJJL': 3,
#  'JRJJJLJ': 3,
#  'LLRJRJJ': 3,
#  'RJRJJLR': 3,
#  'JLRJRLR': 3,
#  'JJLJRRJ': 3,
#  'LJRRJLR': 3,
#  'JRRJLRJ': 3,
#  'RJLRJLJ': 3,
#  'JRJLJRJ': 3,
#  'RRRRJRJ': 3,
#  'RRJRJJJ': 3,
#  'RJJJJJL': 3,
#  'JJJRRJJ': 3,
#  'JRJJRJJ': 3,
#  'RRRJRJL': 3,
#  'RJRJLJL': 3,
#  'RJRJJJL': 3,
#  'JRRRJRJ': 3,
#  'LRJRLRJ': 3,
#  'LRJJRJR': 3,
#  'RJRRRJJ': 3,
#  'JRRRJJJ': 3,
#  'RRRJJJJ': 3,
#  'JRRRRRJ': 3,
#  'LJRJRJJ': 3,
#  'JRJRJJL': 3,
#  'RRJRJRJ': 3,
#  'RJJRJJR': 3,
#  'RRJJJJR': 3,
#  'LRJJJLR': 3,
#  'LRJRJJJ': 3,
#  'LLLLRJR': 3,
#  'JRRJLJR': 3,
#  'JRJLRJJ': 3,
#  'JLRJJLR': 3,
#  'JJLRJLJ': 3,
#  'LLLLLRJ': 3,
#  'LRJJRJJ': 3,
#  'JLRLJRJ': 3,
#  'JLJRJLJ': 3,
#  'LJRJLJR': 3,
#  'RRJLRJJ': 3,
#  'RJJRRJL': 3,
#  'JLJLJRJ': 3,
#  'RJLJLJR': 3,
#  'JRRJRLR': 3,
#  'JLJRJLR': 3,
#  'JLRJLJR': 3,
#  'JJRJRRJ': 3,
#  'JRRJLLL': 3,
#  'LLLLLLL': 3,
#  'RJLRJLRJ': 3,
#  'JLJRJJJJ': 3,
#  'JJJJLRLR': 3,
#  'JJJJJLJR': 3,
#  'JJJJRJRJ': 3,
#  'JRJRJRJJ': 3,
#  'JRJRJJRR': 3,
#  'RJRJJRRJ': 3,
#  'JJJJRJJR': 3,
#  'JJRJRRRR': 3,
#  'JRJJRJRJ': 3,
#  'JJRJRJJJ': 3,
#  'JRJRJJJJ': 3,
#  'LJRRJLRJ': 3,
#  'JRJLJRJJ': 3,
#  'LJRJJJJJ': 3,
#  'JJJJJJLR': 3,
#  'JJJJJLRL': 3,
#  'JJJJRRJJ': 3,
#  'JJRJJJJJ': 3,
#  'JJJJJRJR': 3,
#  'LRJJRJRR': 3,
#  'JRJRRRJJ': 3,
#  'RJRRRJJJ': 3,
#  'JJJJLRJJ': 3,
#  'JJRJRJJR': 3,
#  'JJJJRJJJ': 3,
#  'RRJRJRJR': 3,
#  'RJJJJJRJ': 3,
#  'JLRJJJJJ': 3,
#  'JRJJJJJR': 3,
#  'RRJLJRJL': 3,
#  'RJLJRJLJ': 3,
#  'JLJRJLJR': 3,
#  'RJLRJJRJ': 3,
#  'JLJRJLRJ': 3,
#  'JLRJLJRJ': 3,
#  'RJJRJRRJ': 3,
#  'RJLJRJJJJ': 3,
#  'LRJJJJJJJ': 3,
#  'JJJJJJJJL': 3,
#  'JJJJJJJJJ': 3,
#  'JJJJJRJJR': 3,
#  'JJJJRJJRJ': 3,
#  'JJJRJJRJR': 3,
#  'JRJRJJJJJ': 3,
#  'JRJJJJJJJ': 3,
#  'JRJLJRJJJ': 3,
#  'JRJRRRJJJ': 3,
#  'RJJJRJRJJ': 3,
#  'RRJRJRJRJ': 3,
#  'RJLRJJJJJ': 3,
#  'JLRJJJJJJ': 3,
#  'RRJLJRJLJ': 3,
#  'RJLJRJLJR': 3,
#  'RJJJJJJJJL': 3,
#  'JJJJJRJJRJ': 3,
#  'RJLRJJJJJJ': 3,
#  'RRJLJRJLJR': 3,
#  'RJRJRJRJRJ': 3,
#  'LJJJ': 2,
#  'LLRR': 2,
#  'LJJL': 2,
#  'LJLL': 2,
#  'RRRL': 2,
#  'RRLJ': 2,
#  'RLRL': 2,
#  'RLJL': 2,
#  'LRLL': 2,
#  'RLJJ': 2,
#  'JLJRL': 2,
#  'LRJLL': 2,
#  'JJLLR': 2,
#  'JLJJJ': 2,
#  'LJJJR': 2,
#  'RLJRL': 2,
#  'LJRLJ': 2,
#  'JRRLR': 2,
#  'RRLRJ': 2,
#  'RLLRR': 2,
#  'LLRRJ': 2,
#  'JJRRR': 2,
#  'JJRLR': 2,
#  'JLJJL': 2,
#  'LJJLL': 2,
#  'LRLRR': 2,
#  'RLRRR': 2,
#  'LRRRJ': 2,
#  'LJLLJ': 2,
#  'JJLLJ': 2,
#  'LRRRL': 2,
#  'RRLJR': 2,
#  'LJRLR': 2,
#  'RJRRL': 2,
#  'LJLRR': 2,
#  'JJJRL': 2,
#  'LRJRR': 2,
#  'JLLLR': 2,
#  'RJLRL': 2,
#  'RJRLJ': 2,
#  'JRLJJ': 2,
#  'RLJJR': 2,
#  'LRRJL': 2,
#  'LRJJLJ': 2,
#  'JRLLRJ': 2,
#  'JJRJLR': 2,
#  'LRJLLJ': 2,
#  'RJLLJR': 2,
#  'JJJLJJ': 2,
#  'JLJJRJ': 2,
#  'JJLLRJ': 2,
#  'JLLRJR': 2,
#  'RRJJRR': 2,
#  'LRJLJJ': 2,
#  'JLJJJR': 2,
#  'LJJJRJ': 2,
#  'JJRJLJ': 2,
#  'JJLRLJ': 2,
#  'LRLJRL': 2,
#  'JRLJRR': 2,
#  'LRJJRL': 2,
#  'RJJRLL': 2,
#  'JRLLRR': 2,
#  'RLLRRJ': 2,
#  'LLRRJJ': 2,
#  'RJJRRR': 2,
#  'JJRRRR': 2,
#  'JLRJRJ': 2,
#  'JJRLRJ': 2,
#  'RLRJLJ': 2,
#  'LRLRJL': 2,
#  'JJLJJL': 2,
#  'JLJJLL': 2,
#  'JLRLRR': 2,
#  'LRRRJR': 2,
#  'RRJRRR': 2,
#  'LJLLJR': 2,
#  'LLJRJL': 2,
#  'RJLJJR': 2,
#  'JJJLLJ': 2,
#  'JJLLJR': 2,
#  'JLRRRL': 2,
#  'RRLJRR': 2,
#  'LJRLRJ': 2,
#  'RLRJJR': 2,
#  'LRRJJL': 2,
#  'RJJLJL': 2,
#  'JRLRJR': 2,
#  'RLRJRL': 2,
#  'RRRRJJ': 2,
#  'RRRJJR': 2,
#  'JRJRRL': 2,
#  'LJLRRR': 2,
#  'JLJJRL': 2,
#  'RLRRJR': 2,
#  'LRRJRJ': 2,
#  'RJJJRL': 2,
#  'JJLLLL': 2,
#  'JLLLLR': 2,
#  'RLJRRJ': 2,
#  'LJRJRL': 2,
#  'LRRJJJ': 2,
#  'JJLJLR': 2,
#  'LRJRRJ': 2,
#  'LLRJJR': 2,
#  'RRJJJL': 2,
#  'RJLRLJ': 2,
#  'RLJRJJ': 2,
#  'JLRRRR': 2,
#  'JRJRLJ': 2,
#  'JRLJJR': 2,
#  'JRJLRR': 2,
#  'JRRJRJ': 2,
#  'LRJJRR': 2,
#  'LRJLJL': 2,
#  'LJRJRR': 2,
#  'JLRRJL': 2,
#  'LRRJLJ': 2,
#  'RJLJRR': 2,
#  'RRJRRJ': 2,
#  'JLLLLL': 2,
#  'RJLLLL': 2,
#  'RJRRJL': 2,
#  'LLRJJJ': 2,
#  'JLRJJLJ': 2,
#  'JRJJJJL': 2,
#  'JJJLJRJ': 2,
#  'JJLJRJJ': 2,
#  'LJRJJJR': 2,
#  'JJJRJLR': 2,
#  'JJRJLRJ': 2,
#  'RJLLJRJ': 2,
#  'JRJJJJR': 2,
#  'RJJRRJJ': 2,
#  'RJRRRRJ': 2,
#  'RJJJLJJ': 2,
#  'JJJLJJR': 2,
#  'JLJJRJJ': 2,
#  'JJLLRJR': 2,
#  'JLLRJRJ': 2,
#  'JRJJLRJ': 2,
#  'RJJLRJR': 2,
#  'JJLRJRL': 2,
#  'LRJRLRR': 2,
#  'RLRRJJR': 2,
#  'LRRJJRR': 2,
#  'JRRJJLJ': 2,
#  'RRJJLJR': 2,
#  'JLRJLJJ': 2,
#  'JLJJJRJ': 2,
#  'JJLRLJR': 2,
#  'JLRLJRL': 2,
#  'LRJJRLL': 2,
#  'RJJRLLR': 2,
#  'JJRLLRR': 2,
#  'JRLLRRJ': 2,
#  'RLLRRJJ': 2,
#  'RJJRRRR': 2,
#  'JRRRRJR': 2,
#  'RRRJRJJ': 2,
#  'JJJLRJR': 2,
#  'JJLRJRJ': 2,
#  'LRJRJRJ': 2,
#  'JRLRJLJ': 2,
#  'LRLRJLR': 2,
#  'RJJJJRR': 2,
#  'RJJRJJL': 2,
#  'JJRJJLJ': 2,
#  'JRJJLJJ': 2,
#  'RJJLJJL': 2,
#  'JJLJJLL': 2,
#  'LLRJRJR': 2,
#  'RJJRJJJ': 2,
#  'JJLRLRR': 2,
#  'RRJRJLJ': 2,
#  'LJLLJRJ': 2,
#  'JLLJRJL': 2,
#  'JRJJJLL': 2,
#  'RJJJLLJ': 2,
#  'JJJLLJR': 2,
#  'RRRJLRR': 2,
#  'RRJLRRR': 2,
#  'JRLRJJR': 2,
#  'LRRJJLJ': 2,
#  'JRLRJRL': 2,
#  'RLRJRLR': 2,
#  'JJLRJJR': 2,
#  'JLRJJJR': 2,
#  'LRJJJRJ': 2,
#  'RRRRRJJ': 2,
#  'RRRJJRJ': 2,
#  'RRJJRJR': 2,
#  'JRJRJRR': 2,
#  'JLJJRLJ': 2,
#  'LJJRLJR': 2,
#  'JJRLJRJ': 2,
#  'RLJRJRJ': 2,
#  'JRJJLRL': 2,
#  'RJJLRLR': 2,
#  'LRRJRJR': 2,
#  'RJRRRJR': 2,
#  'RRRJRJR': 2,
#  'JJRJJJR': 2,
#  'JRJJJRL': 2,
#  'RJRLRJJ': 2,
#  'JLLLLRJ': 2,
#  'LLLRJRJ': 2,
#  'RRJRLRR': 2,
#  'RLJRRJL': 2,
#  'LJRRJLJ': 2,
#  'RJLJRJR': 2,
#  'JLJRJRL': 2,
#  'LJRJRLR': 2,
#  'JRJRLRR': 2,
#  'RLRRJJJ': 2,
#  'JJJLJRR': 2,
#  'RJRRJJJ': 2,
#  'LRJJLRJ': 2,
#  'RJJLRJL': 2,
#  'JJLRJJL': 2,
#  'LLLLLLR': 2,
#  'LLLLRJJ': 2,
#  'LLLRJJR': 2,
#  'LLRJJRJ': 2,
#  'JJJJJRR': 2,
#  'RJLRLJR': 2,
#  'RLJRJJJ': 2,
#  'JRRJLRR': 2,
#  'JLRRRRJ': 2,
#  'RJRJRLJ': 2,
#  'JJJRRJR': 2,
#  'JRJJJLR': 2,
#  'LRJJRRJ': 2,
#  'RJJRRJR': 2,
#  'JJRRJRR': 2,
#  'LRJLJLJ': 2,
#  'LJLJRJR': 2,
#  'RJRJRJL': 2,
#  'JRJRJLR': 2,
#  'RJLRRJL': 2,
#  'JLRRJLJ': 2,
#  'LRRJLJR': 2,
#  'RJLJRRJ': 2,
#  'LRLJRJR': 2,
#  'JRJRRJR': 2,
#  'JRJLJLJ': 2,
#  'JLJRJRJ': 2,
#  'JRRJRRJ': 2,
#  'RJRRJRL': 2,
#  'RRJRLRJ': 2,
#  'JRLRJLR': 2,
#  'RJRRRRR': 2,
#  'RRRRJLR': 2,
#  'RRJLRRJ': 2,
#  'JJRRJLL': 2,
#  'RRJLLLL': 2,
#  'JRJRRJL': 2,
#  'LLRJJJL': 2,
#  'JJJLRJL': 2,
#  'LRRRRJL': 2,
#  'JLRJLRJJ': 2,
#  'LRJLRJJL': 2,
#  'LRJLJRJJ': 2,
#  'JRJJJJLR': 2,
#  'JJJLRLRJ': 2,
#  'JJJJJJLJ': 2,
#  'JJJJLJRJ': 2,
#  'JJJLJRJJ': 2,
#  'JLJRJJJR': 2,
#  'LJRJJJRJ': 2,
#  'JJJRJLRJ': 2,
#  'JRJJJJRJ': 2,
#  'JJJRJRJR': 2,
#  'JJRRJJJJ': 2,
#  'JRRJJJJJ': 2,
#  'JJJJJJJR': 2,
#  'JLJRJJJL': 2,
#  'LJRJJJLJ': 2,
#  'JRJJJLJJ': 2,
#  'RJJJLJJR': 2,
#  'RJJRJRJJ': 2,
#  'JJLLRJRJ': 2,
#  'RJJLRJRL': 2,
#  'JJLRJRLR': 2,
#  'JLRJRLRR': 2,
#  'LRJRLRRJ': 2,
#  'JRLRRJJR': 2,
#  'JJLJRRJL': 2,
#  'JLJRRJLR': 2,
#  'LRJLRJJR': 2,
#  'LRJJRLLR': 2,
#  'RJJRLLRR': 2,
#  'JJRLLRRJ': 2,
#  'JRLLRRJJ': 2,
#  'JRRRRJRJ': 2,
#  'RRRJRJJJ': 2,
#  'RRJRJJJJ': 2,
#  'RJJJJLRJ': 2,
#  'JJJLRJRJ': 2,
#  'LRJRJRJJ': 2,
#  'JRJJJJJL': 2,
#  'RJJJJJLR': 2,
#  'LRLRJLRJ': 2,
#  'LRJLRJJJ': 2,
#  'RJJJJRRJ': 2,
#  'RJJRJJLJ': 2,
#  'JJRJJLJJ': 2,
#  'RJJLJJLL': 2,
#  'RJRJJRJJ': 2,
#  'RJJRJJJJ': 2,
#  'RRRJRJLJ': 2,
#  'RRJRJLJL': 2,
#  'LJLLJRJL': 2,
#  'RJRJJJLL': 2,
#  'RJJJLLJR': 2,
#  'JRRRJRJL': 2,
#  'JRLRJRLR': 2,
#  'RLRJRLRJ': 2,
#  'LRJRLRJL': 2,
#  'JLRJJRJR': 2,
#  'JJRJRRRJ': 2,
#  'JRRRJJJJ': 2,
#  'JRRRRRJJ': 2,
#  'RRRJJRJR': 2,
#  'RJJRJRJR': 2,
#  'RJRJRJRR': 2,
#  'RJJJJRJJ': 2,
#  'LJJRLJRJ': 2,
#  'RLJRJRJJ': 2,
#  'RJJJJJJR': 2,
#  'JRJRJJLR': 2,
#  'RJJRJJRJ': 2,
#  'RJRRRJRJ': 2,
#  'JJJRRJJJ': 2,
#  'RRJJJJJR': 2,
#  'JJJRJJJR': 2,
#  'JLLLLRJR': 2,
#  'LLLLRJRJ': 2,
#  'LJRRJLJR': 2,
#  'JRRJLJRJ': 2,
#  'JLJRJRLR': 2,
#  'LJRJRLRR': 2,
#  'JRJRLRRJ': 2,
#  'JRLRRJJJ': 2,
#  'JJJLJRRJ': 2,
#  'RJRRJJJJ': 2,
#  'JRRJJJJR': 2,
#  'RRJJJJRJ': 2,
#  'RJLRJJLR': 2,
#  'JLRJJLRJ': 2,
#  'LJRJLRJJ': 2,
#  'JJJJJLRJ': 2,
#  'JJJLRJJL': 2,
#  'LLLLLLRJ': 2,
#  'LLLLLRJJ': 2,
#  'LLLLRJJR': 2,
#  'LLLRJJRJ': 2,
#  'RJJJJJRR': 2,
#  'JJJJJRRJ': 2,
#  'RJLRLJRJ': 2,
#  'LJRJLJRJ': 2,
#  'JRJJJRJR': 2,
#  'JRRJLRJJ': 2,
#  'JLRJJRJJ': 2,
#  'LRJJRJJR': 2,
#  'JRJJRRJL': 2,
#  'JRJJJLRJ': 2,
#  'RJJRRJRR': 2,
#  'JRJLRJLR': 2,
#  'JLJLJRJR': 2,
#  'JRJRJRJL': 2,
#  'RJLRRJLJ': 2,
#  'JLRRJLJR': 2,
#  'LRRJLJRJ': 2,
#  'RJLJRRJL': 2,
#  'RRJLRJJJ': 2,
#  'JLRLJRJR': 2,
#  'JRJLJLJR': 2,
#  'RJLJLJRJ': 2,
#  'RJRRJRLR': 2,
#  'JRRJRLRJ': 2,
#  'RJRLRJLR': 2,
#  'JRLRJLRJ': 2,
#  'LJRJLRJL': 2,
#  'LRJLJRJL': 2,
#  'RJLJRJLR': 2,
#  'JRJRRRRR': 2,
#  'RJRRRRRJ': 2,
#  'RJJRRJLL': 2,
#  'JJRRJLLL': 2,
#  'JRRJLLLL': 2,
#  'LLLLLLLL': 2,
#  'JJRJRRJL': 2,
#  'LLRJJJLR': 2,
#  'LRJJJLRJ': 2,
#  'RJJJLRJL': 2,
#  'JJJLRJLJ': 2,
#  'JJLRJLJR': 2,
#  'RJLRJLRJJ': 2,
#  'JLRJLRJJL': 2,
#  'LRJLJRJJJ': 2,
#  'JJJJLRLRJ': 2,
#  'JJJJJJJLJ': 2,
#  'JJJJJJLJR': 2,
#  'JJJJJLJRJ': 2,
#  'JJJJLJRJJ': 2,
#  'JLJRJJJRJ': 2,
#  'JJJRJRJRJ': 2,
#  'JRJRJRJJR': 2,
#  'JRJRJJRRJ': 2,
#  'JJRRJJJJJ': 2,
#  'JJJJJJJRJ': 2,
#  'JJJJJJRJJ': 2,
#  'JRJJRJRRR': 2,
#  'RJJRJRRRR': 2,
#  'RJLJRJJJL': 2,
#  'JRJJJLJJR': 2,
#  'JJRJJRJRJ': 2,
#  'JRJJRJRJJ': 2,
#  'JJRJRJJJJ': 2,
#  'RJRJJJJJJ': 2,
#  'RJJJJJJJL': 2,
#  'RJJLRJRLR': 2,
#  'JLRJRLRRJ': 2,
#  'RJRLRRJJR': 2,
#  'JLJRRJLRJ': 2,
#  'JLJRJJJJJ': 2,
#  'LJRJJJJJJ': 2,
#  'RLRJLRJJR': 2,
#  'LRJJRLLRR': 2,
#  'RJJRLLRRJ': 2,
#  'JJRLLRRJJ': 2,
#  'RRRJRJJJJ': 2,
#  'LRJRJRJJR': 2,
#  'JRJJJJJLR': 2,
#  'RJJJJJLRL': 2,
#  'JJJJJLRLR': 2,
#  'RLRJLRJJJ': 2,
#  'LRJLRJJJJ': 2,
#  'RJJJJRRJJ': 2,
#  'RJJRJJLJJ': 2,
#  'RJRJRJJRJ': 2,
#  'JRJRJJRJJ': 2,
#  'RJJRJJJJJ': 2,
#  'RRRJRJLJL': 2,
#  'JJJJJJRJR': 2,
#  'JJJJJRJRJ': 2,
#  'JJJJRJRJJ': 2,
#  ...}

# %%
def getSizeNOnly(pattern_dict, size):
    return {k:v for (k,v) in pattern_dict.items() if len(k) == size}

# %%
G = nx.DiGraph()

nodes_subset = dict()

for pattern, occur in getSizeNOnly(all_patterns, 4).items():
    for i in range(len(pattern)-1):
        if(G.has_edge(pattern[i] + '_' + str(i), pattern[i+1]+ '_' + str(i+1))):
            G[pattern[i] + '_' + str(i)][pattern[i+1]+ '_' + str(i+1)]["weight"] += (occur/5)
        else:
            G.add_edge(pattern[i] + '_' + str(i), pattern[i+1]+ '_' + str(i+1), weight=occur/5)

    for i in range(len(pattern)):
        if((pattern[i] + '_' + str(i)) not in nodes_subset.keys()):
            nodes_subset[pattern[i] + '_' + str(i)] = {'subset': i}

nx.set_node_attributes(G, nodes_subset)

# %%
fig, ax = plt.subplots()
pos=nx.multipartite_layout(G) # pos = nx.nx_agraph.graphviz_layout(G)

for name, coord in pos.items():
    if(name[0] == 'R'):
        pos[name][1] = -1 
    if(name[0] == 'J'):
        pos[name][1] = 0 
    if(name[0] == 'L'):
        pos[name][1] = 1

widths = [w for w in nx.get_edge_attributes(G, 'weight').values()]
print(nx.get_edge_attributes(G, 'weight'))
nx.draw_networkx(G, pos, ax=ax, width=widths)

ax.set_axis_off()
plt.show()
# Out:
# {('J_0', 'J_1'): 46.4, ('J_0', 'R_1'): 40.0, ('J_0', 'L_1'): 23.2, ('J_1', 'J_2'): 46.599999999999994, ('J_1', 'R_2'): 40.0, ('J_1', 'L_2'): 23.199999999999996, ('J_2', 'J_3'): 46.8, ('J_2', 'R_3'): 40.0, ('J_2', 'L_3'): 23.0, ('R_1', 'J_2'): 49.39999999999999, ('R_1', 'R_2'): 19.599999999999998, ('R_1', 'L_2'): 9.600000000000001, ('R_0', 'J_1'): 49.599999999999994, ('R_0', 'R_1'): 19.599999999999998, ('R_0', 'L_1'): 9.6, ('R_2', 'J_3'): 49.4, ('R_2', 'R_3'): 19.6, ('R_2', 'L_3'): 9.6, ('L_1', 'R_2'): 19.0, ('L_1', 'J_2'): 13.8, ('L_1', 'L_2'): 8.4, ('L_0', 'J_1'): 13.8, ('L_0', 'R_1'): 18.999999999999996, ('L_0', 'L_1'): 8.399999999999999, ('L_2', 'R_3'): 19.000000000000004, ('L_2', 'J_3'): 13.799999999999999, ('L_2', 'L_3'): 8.4}

# %%
#pattern_occur is a dict with the following formar --> {str(pattern): n_occur, ...}
#draws multipartite graph
def drawGraphFromPatterns(pattern_occur: dict, size_pattern: int):

    G = nx.DiGraph()
    nodes_subset = dict()


    for k, v in getSizeNOnly(pattern_occur, size_pattern).items():
        for i in range(len(k)-1):
            if(G.has_edge(k[i]  + str(i), k[i+1] + str(i+1))):
                G[k[i]  + str(i)][k[i+1] + str(i+1)]["weight"] += v
            else:
                G.add_edge(k[i]  + str(i), k[i+1] + str(i+1), weight=v)

        for i in range(len(k)):
            if((k[i]  + str(i)) not in nodes_subset.keys()):
                nodes_subset[k[i]  + str(i)] = {'subset': i}


    nx.set_node_attributes(G, nodes_subset)

    fig, ax = plt.subplots()
    
    pos=nx.multipartite_layout(G)

    node_colors = ['tab:green', 'tab:green', 'tab:green', 'tab:green', 'tab:red', 'tab:red', 'tab:red', 'tab:red', 'tab:blue', 'tab:blue', 'tab:blue', 'tab:blue']

    for name, coord in pos.items():
        if(name[0] == 'R'):
            pos[name][1] = -1 
        if(name[0] == 'J'):
            pos[name][1] = 0 
        if(name[0] == 'L'):
            pos[name][1] = 1
    
    weights = nx.get_edge_attributes(G, 'weight').values()
    widths = [3*(((w-min(weights))/(max(weights)-min(weights)))+0.1) for w in weights]

    print(nx.get_edge_attributes(G, 'weight'))
    nx.draw_networkx(G, pos, ax=ax, node_size=600, node_color=node_colors, width=widths)

    ax.set_axis_off()
    plt.show()

drawGraphFromPatterns(all_patterns, 4)
# Out:
# {('J0', 'J1'): 232, ('J0', 'R1'): 200, ('J0', 'L1'): 116, ('J1', 'J2'): 233, ('J1', 'R2'): 200, ('J1', 'L2'): 116, ('J2', 'J3'): 234, ('J2', 'R3'): 200, ('J2', 'L3'): 115, ('R1', 'J2'): 247, ('R1', 'R2'): 98, ('R1', 'L2'): 48, ('R0', 'J1'): 248, ('R0', 'R1'): 98, ('R0', 'L1'): 48, ('R2', 'J3'): 247, ('R2', 'R3'): 98, ('R2', 'L3'): 48, ('L1', 'R2'): 95, ('L1', 'J2'): 69, ('L1', 'L2'): 42, ('L0', 'J1'): 69, ('L0', 'R1'): 95, ('L0', 'L1'): 42, ('L2', 'R3'): 95, ('L2', 'J3'): 69, ('L2', 'L3'): 42}

# %%
min(nx.get_edge_attributes(G, 'weight').values())
# Out:
# 8.399999999999999

# %%
G.nodes()
# Out:
# NodeView(('J_0', 'J_1', 'J_2', 'J_3', 'R_1', 'R_3', 'R_0', 'R_2', 'L_1', 'L_0', 'L_2', 'L_3'))
