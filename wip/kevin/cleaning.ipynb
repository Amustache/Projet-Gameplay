# %%
import numpy as np
import pandas as pd
import glob
import os
from pathlib import Path
from itertools import product

DATA = '/Users/caldera/Documents/EPFL/GAP/Project/Projet-Gameplay/wip/kevin/data'

#right, left, jump, fire
REMAP = {'Key.right': 'R', 
         'Key.left': 'L', 
         '\'d\'': 'J', 
         'Key.space': 'J',
         'Key.up': 'J'}

FPS = 60
N_FRAME = [2*FPS, 10*FPS, 60*FPS, 300*FPS]
BLOCK_TIME = ['2s', '10s', '1min', '5min']
MIN_OCCUR = [1, 2, 5, 20]
p3 = [''.join(p) for n in range(2,4) for p in product('RLJ', repeat=n)]
p4 = [''.join(p) for n in range(2,5) for p in product('RLJ', repeat=n)]
p10 = [''.join(p) for n in range(2,11) for p in product('RLJ', repeat=n)]
p15 = [''.join(p) for n in range(2,16) for p in product('RLJ', repeat=n)]
PATTERN_MAX_LENGTH = [3, 4, 10, 15]
PATTERNS = [p3, p4, p10, p15]


def slice_keylog_file(frames_and_inputs_list, predicted=True):

    for i, run in enumerate(frames_and_inputs_list):
        for block_time, block_size in zip(BLOCK_TIME, N_FRAME):
            block = list()
            n_block = int(run.FRAME.max()/block_size)

            for period in range(n_block):
                slice = run[(run.FRAME >= period*block_size) & (run.FRAME < (period+1)*block_size)]
                block.append(slice)

                if predicted:
                    save_path = DATA + '/sliced_logs/predicted/run_{}/{}/slice{}.csv'.format(i, block_time, period) 
                else:
                    save_path = DATA + '/sliced_logs/ground_truth/run_{}/{}/slice{}.csv'.format(i, block_time, period) 

                filepath2 = Path(save_path)  
                filepath2.parent.mkdir(parents=True, exist_ok=True)  
                slice.to_csv(filepath2) 


#read csv file (inputs), return list of pressed keys (down only and standardized as LRJ)
# slices the file au passage
def read_and_standardize_logs(csv_file, predicted=True):

    data = pd.read_csv(csv_file)
    #data['run_number'] = i

    main_keys = data.KEY.value_counts().keys()[:4].tolist() #might not be necessary for predicted inputs
    data =  data[data.KEY.isin(main_keys)]


    keylogs = data[(data.KEY != '\'a\'') & (data.KEY != 'Key.enter') & (data.KEY != '\'s\'')] # A modifier quand on saura ce que predit exactement le modele
    keylogs = keylogs.replace({"KEY": REMAP}) #idem
    keylogs = keylogs[keylogs.STATUS == 'DOWN'] #on garde que les touches pressées atm

    #slice_keylog_file(frames_and_inputs_list, predicted)

    return keylogs



#inputs_log : must contain a "KEY" column with only letter L,R,J
#return Series of pattern count in decreasing order; the pattern is the index
def get_pattern_count(standardized_inputs, max_pattern_size, min_pattern_occur=10):
    d=dict()
    keys_as_str = standardized_inputs.KEY.str.cat()
    
    for pattern in PATTERNS[max_pattern_size]:
        d[pattern]=keys_as_str.count(pattern)

    frequencies = pd.Series(dict(sorted(d.items(), key=lambda x: x[1], reverse=True)))
    
    return (frequencies[frequencies > min_pattern_occur]).to_dict()

# %%
frequency_dataset = list()

files = sorted(Path(DATA + '/keylogs/ground_truth').glob('*.csv')) #ne preserve pas l'ordre

#liste des keylogs de la run i à la position i 
frames_and_inputs_list = list()

for i, f in enumerate(files):
    data = pd.read_csv(f)
    data['run_number'] = i

    main_keys = data.KEY.value_counts().keys()[:4].tolist()
    data =  data[data.KEY.isin(main_keys)]

    keylogs = data[(data.KEY != '\'a\'') & (data.KEY != 'Key.enter') & (data.KEY != '\'s\'')] # A modifier quand on saura ce que predit exactement le modele
    keylogs = keylogs.replace({"KEY": REMAP}) #idem
    keylogs = keylogs[keylogs.STATUS == 'DOWN'] #on garde que les touches pressées atm

    frames_and_inputs_list.append(keylogs)

for i, run in enumerate(frames_and_inputs_list):
    for block_time, block_size, max_pattern_size, min_occur in zip(BLOCK_TIME, N_FRAME, PATTERN_MAX_LENGTH, MIN_OCCUR):
        n_block = int(run.FRAME.max()/block_size)

        for period in range(n_block):
            slice = run[(run.FRAME >= period*block_size) & (run.FRAME < (period+1)*block_size)]

            freqs = get_pattern_count(slice, max_pattern_size, min_occur)

            for pattern in freqs.keys():
                frequency_dataset.append([i, block_time, period, pattern, freqs[pattern]])
            
            save_path = DATA + '/test/sliced_logs/ground_truth/run_{}/{}/slice{}.csv'.format(i, block_time, period) 
            filepath2 = Path(save_path)  
            filepath2.parent.mkdir(parents=True, exist_ok=True)  
            slice.to_csv(filepath2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [163], line 28
#      25 for period in range(n_block):
#      26     slice = run[(run.FRAME >= period*block_size) & (run.FRAME < (period+1)*block_size)]
# ---> 28     freqs = get_pattern_count(slice, max_pattern_size, min_occur)
#      30     for pattern in freqs.keys():
#      31         frequency_dataset.append([i, block_time, period, pattern, freqs[pattern]])
#
# Cell In [159], line 82, in get_pattern_count(standardized_inputs, max_pattern_size, min_pattern_occur)
#      79 keys_as_str = standardized_inputs.KEY.str.cat()
#      81 for pattern in PATTERNS[max_pattern_size]:
# ---> 82     d[pattern]=keys_as_str.count(pattern)
#      84 frequencies = pd.Series(dict(sorted(d.items(), key=lambda x: x[1], reverse=True)))
#      86 return (frequencies[frequencies > min_pattern_occur]).to_dict()
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame(frequency_dataset)

df.to_csv('/Users/caldera/Documents/EPFL/GAP/Project/Projet-Gameplay/wip/kevin/data/test/freq_dataset.csv')

# %%
runs
# Out:
# [      FRAME        KEY STATUS  run_number
#  2       405  Key.right   DOWN           0
#  3       428  Key.right     UP           0
#  4       437        'd'   DOWN           0
#  5       457        'd'     UP           0
#  6       472  Key.right   DOWN           0
#  ...     ...        ...    ...         ...
#  1945  41712        's'   DOWN           0
#  1946  41738        's'     UP           0
#  1947  41744        'd'   DOWN           0
#  1948  41760        'd'     UP           0
#  1949  41763  Key.right     UP           0
#
#  [1920 rows x 4 columns],
#         FRAME        KEY STATUS  run_number
#  4        186  Key.right   DOWN           1
#  5        191        's'   DOWN           1
#  6        302  Key.space   DOWN           1
#  7        311  Key.space     UP           1
#  8        330  Key.right     UP           1
#  ...      ...        ...    ...         ...
#  6729  130284   Key.left     UP           1
#  6730  130295  Key.right   DOWN           1
#  6731  130323  Key.right     UP           1
#  6732  130323  Key.space   DOWN           1
#  6733  130332  Key.space     UP           1
#
#  [6510 rows x 4 columns],
#       FRAME        KEY STATUS  run_number
#  4      520  Key.enter   DOWN           2
#  5      523  Key.enter     UP           2
#  6      650  Key.enter   DOWN           2
#  7      653  Key.enter     UP           2
#  8      724  Key.right   DOWN           2
#  ..     ...        ...    ...         ...
#  136   3367        'd'     UP           2
#  137   3388        'd'   DOWN           2
#  138   3397        'd'     UP           2
#  139   3404  Key.right     UP           2
#  140   3452   Key.left   DOWN           2
#
#  [133 rows x 4 columns],
#       FRAME        KEY STATUS  run_number
#  6      382        'd'   DOWN           3
#  7      389        'd'     UP           3
#  8      398        'd'   DOWN           3
#  9      404        'd'     UP           3
#  10     419        's'   DOWN           3
#  ..     ...        ...    ...         ...
#  835  18321  Key.right     UP           3
#  836  18368  Key.right   DOWN           3
#  837  18377        'd'   DOWN           3
#  838  18418        'd'     UP           3
#  839  18425  Key.right     UP           3
#
#  [794 rows x 4 columns],
#       FRAME        KEY STATUS  run_number
#  2      250  Key.right   DOWN           4
#  3      268  Key.right     UP           4
#  6      293        'd'   DOWN           4
#  7      312        'd'     UP           4
#  8      318        'd'   DOWN           4
#  ..     ...        ...    ...         ...
#  905  20231  Key.right     UP           4
#  906  20347  Key.right   DOWN           4
#  907  20375        'd'   DOWN           4
#  908  20421  Key.right     UP           4
#  909  20424        'd'     UP           4
#
#  [858 rows x 4 columns],
#        FRAME        KEY STATUS  run_number
#  4       689  Key.right   DOWN           5
#  5       726        's'   DOWN           5
#  6       774        's'     UP           5
#  7       785  Key.right     UP           5
#  8       788  Key.right   DOWN           5
#  ...     ...        ...    ...         ...
#  1907  40399   Key.left   DOWN           5
#  1908  40402  Key.right     UP           5
#  1909  40404  Key.right   DOWN           5
#  1910  40406  Key.right     UP           5
#  1911  40448   Key.left     UP           5
#
#  [1808 rows x 4 columns],
#        FRAME        KEY STATUS  run_number
#  2       342  Key.right   DOWN           6
#  3       378  Key.space   DOWN           6
#  4       436  Key.space     UP           6
#  5       449     Key.up   DOWN           6
#  6       449  Key.right     UP           6
#  ...     ...        ...    ...         ...
#  1037  23161     Key.up   DOWN           6
#  1038  23164   Key.left   DOWN           6
#  1039  23164  Key.right     UP           6
#  1040  23168     Key.up     UP           6
#  1041  23203   Key.left     UP           6
#
#  [1020 rows x 4 columns],
#       FRAME        KEY STATUS  run_number
#  4      806  Key.right   DOWN           7
#  5      808  Key.right     UP           7
#  6      811        's'   DOWN           7
#  7      822  Key.right   DOWN           7
#  8      911        'd'   DOWN           7
#  ..     ...        ...    ...         ...
#  455  11865        'd'   DOWN           7
#  456  11869   Key.left     UP           7
#  457  11890        'd'     UP           7
#  458  11893        's'     UP           7
#  459  11906  Key.right     UP           7
#
#  [444 rows x 4 columns],
#       FRAME        KEY STATUS  run_number
#  2      403        'd'   DOWN           8
#  3      411        'd'     UP           8
#  4      439        's'   DOWN           8
#  5      465        's'     UP           8
#  6      482        's'   DOWN           8
#  ..     ...        ...    ...         ...
#  917  24672  Key.right   DOWN           8
#  918  24674   Key.left     UP           8
#  919  24678        'd'   DOWN           8
#  920  24717  Key.right     UP           8
#  921  24717        'd'     UP           8
#
#  [906 rows x 4 columns],
#       FRAME        KEY STATUS  run_number
#  2      437  Key.right   DOWN           9
#  3      487   Key.left   DOWN           9
#  4      488  Key.right     UP           9
#  5      521   Key.left     UP           9
#  6      531  Key.right   DOWN           9
#  ..     ...        ...    ...         ...
#  817  16043  Key.right   DOWN           9
#  818  16047        'd'     UP           9
#  819  16082        'd'   DOWN           9
#  820  16092        'd'     UP           9
#  821  16096  Key.right     UP           9
#
#  [810 rows x 4 columns],
#        FRAME        KEY STATUS  run_number
#  4       346  Key.right   DOWN          10
#  5       491        'd'   DOWN          10
#  6       517        'd'     UP          10
#  7       519  Key.right     UP          10
#  8       534   Key.left   DOWN          10
#  ...     ...        ...    ...         ...
#  2929  67301        'd'     UP          10
#  2930  67356        'd'   DOWN          10
#  2931  67363        'd'     UP          10
#  2932  67367        's'     UP          10
#  2933  67372  Key.right     UP          10
#
#  [2862 rows x 4 columns],
#        FRAME        KEY STATUS  run_number
#  6       309  Key.right   DOWN          11
#  7       340        'd'   DOWN          11
#  8       351        'd'     UP          11
#  9       463  Key.right     UP          11
#  10      474        'd'   DOWN          11
#  ...     ...        ...    ...         ...
#  1183  27979        'd'   DOWN          11
#  1184  28006  Key.right     UP          11
#  1185  28006        'd'     UP          11
#  1186  28027   Key.left   DOWN          11
#  1187  28068   Key.left     UP          11
#
#  [1180 rows x 4 columns],
#       FRAME        KEY STATUS  run_number
#  2      690  Key.right   DOWN          12
#  3      704  Key.space   DOWN          12
#  4      806     Key.up   DOWN          12
#  5      820     Key.up     UP          12
#  6      843  Key.space     UP          12
#  ..     ...        ...    ...         ...
#  373   7363  Key.right     UP          12
#  374   7367  Key.right   DOWN          12
#  375   7379  Key.right     UP          12
#  376   7566  Key.space   DOWN          12
#  377   7575  Key.space     UP          12
#
#  [376 rows x 4 columns],
#       FRAME        KEY STATUS  run_number
#  2      301  Key.right   DOWN          13
#  3      360        's'   DOWN          13
#  4      465        'd'   DOWN          13
#  5      477        'd'     UP          13
#  6      478  Key.right     UP          13
#  ..     ...        ...    ...         ...
#  721  15800        'd'     UP          13
#  722  15910        'd'   DOWN          13
#  723  15971        'd'     UP          13
#  724  15971        's'     UP          13
#  725  15976  Key.right     UP          13
#
#  [708 rows x 4 columns],
#       FRAME        KEY STATUS  run_number
#  2      421  Key.right   DOWN          14
#  3      434  Key.right     UP          14
#  4      475  Key.right   DOWN          14
#  5      489  Key.right     UP          14
#  6      512  Key.right   DOWN          14
#  ..     ...        ...    ...         ...
#  567  16175        'd'     UP          14
#  568  16586  Key.right   DOWN          14
#  569  16629        'd'   DOWN          14
#  570  16637        'd'     UP          14
#  571  16693  Key.right     UP          14
#
#  [538 rows x 4 columns],
#       FRAME        KEY STATUS  run_number
#  2      224  Key.right   DOWN          15
#  3      228  Key.right     UP          15
#  4      279  Key.right   DOWN          15
#  5      301        'd'   DOWN          15
#  6      305        'd'     UP          15
#  ..     ...        ...    ...         ...
#  803  11350  Key.right     UP          15
#  804  11361  Key.right   DOWN          15
#  805  11368        'd'   DOWN          15
#  806  11391        'd'     UP          15
#  807  11415  Key.right     UP          15
#
#  [746 rows x 4 columns],
#        FRAME        KEY STATUS  run_number
#  0       237        'd'   DOWN          16
#  1       255        'd'     UP          16
#  2       343        'd'   DOWN          16
#  3       362        'd'     UP          16
#  4       376  Key.right   DOWN          16
#  ...     ...        ...    ...         ...
#  2615  58746        'd'     UP          16
#  2618  58936        'd'   DOWN          16
#  2622  58976        'd'     UP          16
#  2625  59006  Key.right   DOWN          16
#  2627  59044  Key.right     UP          16
#
#  [2526 rows x 4 columns],
#        FRAME        KEY STATUS  run_number
#  4       836  Key.right   DOWN          17
#  5       839  Key.right     UP          17
#  6       939  Key.right   DOWN          17
#  7       962        's'   DOWN          17
#  8       991        's'     UP          17
#  ...     ...        ...    ...         ...
#  2121  40590  Key.right   DOWN          17
#  2122  40632        'd'     UP          17
#  2123  40635   Key.left   DOWN          17
#  2124  40635  Key.right     UP          17
#  2125  40658   Key.left     UP          17
#
#  [2044 rows x 4 columns],
#       FRAME        KEY STATUS  run_number
#  6      258  Key.right   DOWN          18
#  7      301        'd'   DOWN          18
#  8      329        'd'     UP          18
#  9      342        's'   DOWN          18
#  10     380  Key.right     UP          18
#  ..     ...        ...    ...         ...
#  523  12568        's'   DOWN          18
#  524  12603        's'     UP          18
#  525  12609        's'   DOWN          18
#  528  12656        's'     UP          18
#  529  12657  Key.right     UP          18
#
#  [522 rows x 4 columns],
#       FRAME        KEY STATUS  run_number
#  2      378  Key.right   DOWN          19
#  3      426        's'   DOWN          19
#  4      508        'd'   DOWN          19
#  5      515        'd'     UP          19
#  6      555  Key.right     UP          19
#  ..     ...        ...    ...         ...
#  267   6492        'd'   DOWN          19
#  268   6517        'd'     UP          19
#  269   6545        'd'   DOWN          19
#  270   6614        'd'     UP          19
#  271   6619  Key.right     UP          19
#
#  [266 rows x 4 columns],
#        FRAME        KEY STATUS  run_number
#  8       428  Key.right   DOWN          20
#  9       580        'd'   DOWN          20
#  10      588        'd'     UP          20
#  11      598  Key.right     UP          20
#  12      607        's'   DOWN          20
#  ...     ...        ...    ...         ...
#  1537  34224   Key.left     UP          20
#  1538  34235  Key.right   DOWN          20
#  1539  34287        'd'   DOWN          20
#  1540  34294        'd'     UP          20
#  1541  34347  Key.right     UP          20
#
#  [1492 rows x 4 columns],
#        FRAME        KEY STATUS  run_number
#  2       242  Key.right   DOWN          21
#  3       274        's'   DOWN          21
#  4       374        'd'   DOWN          21
#  5       387  Key.right     UP          21
#  6       387        'd'     UP          21
#  ...     ...        ...    ...         ...
#  1667  35204        'd'     UP          21
#  1668  35229        'd'   DOWN          21
#  1669  35257        'd'     UP          21
#  1670  35263        's'     UP          21
#  1671  35271  Key.right     UP          21
#
#  [1600 rows x 4 columns],
#        FRAME        KEY STATUS  run_number
#  4       531  Key.right   DOWN          22
#  5       544  Key.right     UP          22
#  6       584  Key.right   DOWN          22
#  7       600  Key.right     UP          22
#  8       610        'd'   DOWN          22
#  ...     ...        ...    ...         ...
#  1035  31765        'd'   DOWN          22
#  1036  31797        'd'     UP          22
#  1037  31803  Key.right     UP          22
#  1038  31811  Key.right   DOWN          22
#  1039  31844  Key.right     UP          22
#
#  [1024 rows x 4 columns]]

# %%
#all inputs
'''
all_inputs = pd.concat(runs, ignore_index=True)
all_inputs

all_inputs = all_inputs[(all_inputs.KEY != '\'a\'') & (all_inputs.KEY != 'Key.enter') & (all_inputs.KEY != '\'s\'')]

only_R_L_J = all_inputs.replace({"KEY": REMAP})

filepath = Path(DATA + '/all_inputs_concat.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
only_R_L_J.to_csv(filepath) 

pressed_keys = only_R_L_J[only_R_L_J.STATUS == 'DOWN']

all_pressed_keys = pressed_keys.KEY 

all_pressed_keys

'''
# Out:
# '\nall_inputs = pd.concat(runs, ignore_index=True)\nall_inputs\n\nall_inputs = all_inputs[(all_inputs.KEY != \'\'a\'\') & (all_inputs.KEY != \'Key.enter\') & (all_inputs.KEY != \'\'s\'\')]\n\nonly_R_L_J = all_inputs.replace({"KEY": REMAP})\n\nfilepath = Path(DATA + \'/all_inputs_concat.csv\')  \nfilepath.parent.mkdir(parents=True, exist_ok=True)  \nonly_R_L_J.to_csv(filepath) \n\npressed_keys = only_R_L_J[only_R_L_J.STATUS == \'DOWN\']\n\nall_pressed_keys = pressed_keys.KEY \n\nall_pressed_keys\n\n'

# %%
#TOTAL FREQUENCIES OF PATTERNS OVER ALL GROUND TRUTH
pattern_freq = list()

for run in frames_and_inputs_list:
    keys_as_str = run.KEY.str.cat()

    d=dict()
    for i in PATTERNS:
        d[i]=keys_as_str.count(i)

    frequencies = dict(sorted(d.items(), key=lambda x: x[1], reverse=True))
    frequencies = pd.Series(frequencies)
    frequencies = frequencies[frequencies > 10]
    
    pattern_freq.append(frequencies)

# %%
aggreg = pd.Series({'RJ': 0})

for s in pattern_freq:
    aggreg = aggreg.add(s, fill_value=0)

aggreg.sort_values(ascending=False).astype(int).head(20)
# Out:
# RJ      2606
# JR      2192
# JJ      1679
# JL      1245
# JRJ     1033
# LR      1017
# RR       947
# RJJ      920
# LJ       835
# RJR      761
# JJJ      735
# RRJ      677
# JJR      667
# RJL      642
# RL       611
# JRR      576
# LRJ      553
# JLR      479
# LJR      458
# RJJJ     455
# dtype: int64

# %%
aggreg.describe()
# Out:
# count     249.000000
# mean      135.349398
# std       301.631549
# min        11.000000
# 25%        14.000000
# 50%        29.000000
# 75%       108.000000
# max      2606.000000
# dtype: float64

# %%
for i, run in enumerate(frames_and_inputs_list):
    for block_time, block_size in zip(BLOCK_TIME, N_FRAME):
        block = list()
        n_block = int(run.FRAME.max()/block_size)

        for period in range(n_block):
            slice = run[(run.FRAME >= period*block_size) & (run.FRAME < (period+1)*block_size)]
            block.append(slice)

        
            filepath2 = Path(save_path)  
            filepath2.parent.mkdir(parents=True, exist_ok=True)  
            slice.to_csv(filepath2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [139], line 10
#       7 slice = run[(run.FRAME >= period*block_size) & (run.FRAME < (period+1)*block_size)]
#       8 block.append(slice)
# ---> 10 if predicted:
#      11     save_path = DATA + '/sliced_logs/predicted/run_{}/{}/slice{}.csv'.format(i, block_time, period)
#      12 else:
#
# NameError: name 'predicted' is not defined

# %%
path1 = '/Users/caldera/Documents/EPFL/GAP/Project/Projet-Gameplay/wip/kevin/data/test/sliced_logs/ground_truth'
for i in range(23):
    dir = '/run_{}'.format(i)
    
    for length in BLOCK_TIME:
        if os.path.exists(path1 + dir + '/' + length):
